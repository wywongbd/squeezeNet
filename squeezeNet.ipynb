# %%
import tensorflow as tf
from squeezeNet import SqueezeNet

# %%
from cs231n.data_utils import load_imagenet_val
from matplotlib import pyplot as plt 

X_raw, y, class_names = load_imagenet_val()

plt.figure(figsize=(12, 6))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(X_raw[i])
    plt.title(class_names[y[i]])
    plt.axis('off')
plt.gcf().tight_layout()
plt.show()

# %%
import numpy as np

def get_one_hot(targets, nb_classes):
    return np.eye(nb_classes)[np.array(targets).reshape(-1)]

# %%
from cs231n.image_utils import preprocess_image, deprocess_image

X = np.array([preprocess_image(img) for img in X_raw])

# %%
sess = tf.Session()
net  = SqueezeNet(sess, alpha = 1e-2)

# %%
y_one_hot = get_one_hot(y, 1000)

# %%
net.train_model(X, y_one_hot, epoch = 1000)
# Out:
# Step 1, Minibatch Loss= 357544618885120.0000, Training Accuracy= 0.000
# Step 5, Minibatch Loss= 44264406908928.0000, Training Accuracy= 0.000
# Step 10, Minibatch Loss= 6718169808896.0000, Training Accuracy= 0.000
# Step 15, Minibatch Loss= 1885449093120.0000, Training Accuracy= 0.000
# Step 20, Minibatch Loss= 668951248896.0000, Training Accuracy= 0.040
# Step 25, Minibatch Loss= 206408597504.0000, Training Accuracy= 0.120
# Step 30, Minibatch Loss= 115171393536.0000, Training Accuracy= 0.200
# Step 35, Minibatch Loss= 64016625664.0000, Training Accuracy= 0.160
# Step 40, Minibatch Loss= 34436190208.0000, Training Accuracy= 0.320
# Step 45, Minibatch Loss= 18066053120.0000, Training Accuracy= 0.360
# Step 50, Minibatch Loss= 9405929472.0000, Training Accuracy= 0.560
# Step 55, Minibatch Loss= 4213581312.0000, Training Accuracy= 0.680
# Step 60, Minibatch Loss= 1297753728.0000, Training Accuracy= 0.800
# Step 65, Minibatch Loss= 493320288.0000, Training Accuracy= 0.840
# Step 70, Minibatch Loss= 25185484.0000, Training Accuracy= 0.960
# Step 75, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# Step 80, Minibatch Loss= 0.0000, Training Accuracy= 1.000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-1f1759f04609> in <module>()
# ----> 1 net.train_model(X, y_one_hot, epoch = 1000)
#
# ~\coding_workspace\squeezeNet\squeezeNet.py in train_model(self, X_train, Y_train, epoch)
#      79                         batch_x, batch_y = X_train, Y_train
#      80                         # Run optimization op (backprop)
# ---> 81                         self.sess.run(self.optimize, feed_dict={self.imgs: batch_x, self.target: batch_y})
#      82
#      83                         if step % 5 == 0 or step == 1:
#
# ~\Anaconda3\envs\traders_nlp\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\Anaconda3\envs\traders_nlp\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# ~\Anaconda3\envs\traders_nlp\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~\Anaconda3\envs\traders_nlp\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~\Anaconda3\envs\traders_nlp\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
